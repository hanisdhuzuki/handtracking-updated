# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for Distance
distance = np.array([20, 25, 30, 35, 40, 45, 50, 55, 60, 65, 70])
accuracy_mean = np.array([0.397924, 0.435885, 0.498593, 0.526806, 0.587491, 0.74931, 0.817424, 0.859765, 0.971445, 0.891862, 0.8924])
accuracy_std = np.array([0.320255, 0.369221, 0.359246, 0.366469, 0.322617, 0.301532, 0.188746, 0.132725, 0.02884, 0.104221, 0.103108])

precision_mean = np.array([1.140848, 1.740514, 0.929579, 1.144111, 1.594197, 1.984347, 1.692682, 2.025226, 1.339744, 1.991831, 1.273055])
precision_std = np.array([0.577014, 1.213054, 0.346807, 0.627305, 1.363126, 1.387615, 1.060699, 1.348519, 1.063364, 1.248231, 0.42988])

recall_mean = np.array([0.333333, 0.666667, 0.583333, 0.583333, 0.625, 0.458333, 0.708333, 0.625, 0.666667, 0.5, 0.541667])
recall_std = np.array([0.471405, 0.356348, 0.235702, 0.295468, 0.415474, 0.395912, 0.213623, 0.278174, 0.356348, 0.436436, 0.50198])

f1_mean = np.array([0.433333, 0.5125, 0.570833, 0.6, 0.645343, 0.795833, 0.927315, 0.983333, 1.0, 0.995833, 0.975])
f1_std = np.array([0.371184, 0.446481, 0.424428, 0.414805, 0.377242, 0.323884, 0.179281, 0.030861, 0.0, 0.011785, 0.070711])

latency_mean = np.array([0.544559, 0.614633, 0.643372, 0.675343, 0.738707, 0.908802, 1.005251, 1.050745, 1.015026, 1.080978, 1.025084])
latency_std = np.array([0.421263, 0.495285, 0.409782, 0.441032, 0.40385, 0.362941, 0.179604, 0.081009, 0.100087, 0.121855, 0.066847])

# Plot for Distance vs Mean Accuracy and Std
plt.figure(figsize=(10, 6))
plt.errorbar(distance, accuracy_mean, yerr=accuracy_std, fmt='o-', label='Accuracy', color='#e36b94', capsize=5)
plt.xlabel('Distance (cm)')
plt.ylabel('Mean Accuracy (%)')
plt.title('Distance vs Mean Accuracy with Standard Deviation')
plt.grid(True)
plt.legend()
plt.show()

# Plot for Distance vs Mean Precision and Std
plt.figure(figsize=(10, 6))
plt.errorbar(distance, precision_mean, yerr=precision_std, fmt='o-', label='Precision', color='#7e6be3', capsize=5)
plt.xlabel('Distance (cm)')
plt.ylabel('Mean Precision (%)')
plt.title('Distance vs Mean Precision with Standard Deviation')
plt.grid(True)
plt.legend()
plt.show()

# Plot for Distance vs Mean Recall and Std
plt.figure(figsize=(10, 6))
plt.errorbar(distance, recall_mean, yerr=recall_std, fmt='o-', label='Recall', color='#FFC300', capsize=5)
plt.xlabel('Distance (cm)')
plt.ylabel('Mean Recall (%)')
plt.title('Distance vs Mean Recall with Standard Deviation')
plt.grid(True)
plt.legend()
plt.show()

# Plot for Distance vs Mean F1-score and Std
plt.figure(figsize=(10, 6))
plt.errorbar(distance, f1_mean, yerr=f1_std, fmt='o-', label='F1-Score', color='#3cc184', capsize=5)
plt.xlabel('Distance (cm)')
plt.ylabel('Mean F1-Score (%)')
plt.title('Distance vs Mean F1-Score with Standard Deviation')
plt.grid(True)
plt.legend()
plt.show()

# Plot for Distance vs Mean Latency and Std
plt.figure(figsize=(10, 6))
plt.errorbar(distance, latency_mean, yerr=latency_std, fmt='o-', label='Latency', color='#ff339e', capsize=5)
plt.xlabel('Distance (cm)')
plt.ylabel('Mean Latency (ms)')
plt.title('Distance vs Mean Latency with Standard Deviation')
plt.grid(True)
plt.legend()
plt.show()

# Camera Type Data (Mean and Std)
camera_types = ['External Camera', 'Samsung Galaxy S21']
camera_accuracy_mean = [0.683728, 0.703346]
camera_accuracy_std = [0.311798, 0.330082]

camera_precision_mean = [1.591239, 1.473512]
camera_precision_std = [1.083539, 1.019198]

camera_recall_mean = [0.789305, 0.745118]
camera_recall_std = [0.349723, 0.35324]

camera_f1_mean = [0.854401, 0.836963]
camera_f1_std = [0.362569, 0.363551]

camera_latency_mean = [0.469697, 0.674242]
camera_latency_std = [0.347142, 0.355747]

# Plot for Camera Type vs Mean Accuracy and Std
plt.figure(figsize=(10, 6))
plt.errorbar(camera_types, camera_accuracy_mean, yerr=camera_accuracy_std, fmt='o-', label='Accuracy', color='red', capsize=5)
plt.xlabel('Camera Type')
plt.ylabel('Mean Accuracy (%)')
plt.title('Camera Type vs Mean Accuracy with Standard Deviation')
plt.grid(True)
plt.legend()
plt.show()

# Similar plots can be done for Precision, Recall, F1-score, and Latency for Camera Type

# %%
import pandas as pd

# Data for the summary of average metrics
data = {
    'Factor': ['Distance (cm)', 'Distance (cm)', 'Camera Type', 'Camera Type', 'Lighting Conditions', 'Lighting Conditions'],
    'Levels': ['20.0 - 60.0', '20.0 - 60.0', 'External Webcam', 'Samsung Galaxy S21', 'Dim', 'Bright'],
    'Mean Accuracy (%)': [0.6935, None, 0.6837, 0.7033, 0.67, 0.72],
    'Mean Precision (%)': [1.4520, None, 1.5912, 1.4735, 1.23, 1.84],
    'Mean Recall (%)': [0.5985, None, 0.7893, 0.7451, 0.73, 0.81],
    'Mean F1-score (%)': [0.7838, None, 0.8544, 0.8370, 0.78, 0.91],
    'Mean Latency (ms)': [0.8509, None, 0.4697, 0.6742, 0.47, 0.67]
}

# Create DataFrame
df = pd.DataFrame(data)

# Save to Excel
file_name = 'Average_Metrics_Summary.xlsx'
df.to_excel(file_name, index=False)

print(f"File saved as: {file_name}")
# Out:
# File saved as: Average_Metrics_Summary.xlsx

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the factors
factors = ['Distance', 'Camera', 'Lighting']
accuracy = [0.69, 0.69, 0.70]
precision = [1.53, 1.53, 1.54]
recall = [0.59, 0.77, 0.77]
f1_score = [0.36, 0.85, 0.85]
latency = [1.62, 0.57, 0.57]

# Bar width and positions
bar_width = 0.15
index = np.arange(len(factors))

# Plotting the bars for each metric
plt.figure(figsize=(10, 6))

plt.bar(index, accuracy, bar_width, label='Mean Accuracy (%)', color='#F09D9D')
plt.bar(index + bar_width, precision, bar_width, label='Mean Precision (%)', color='#99CCFF')
plt.bar(index + 2 * bar_width, recall, bar_width, label='Mean Recall (%)', color='#FFCC99')
plt.bar(index + 3 * bar_width, f1_score, bar_width, label='Mean F1-score (%)', color='#66CC99')
plt.bar(index + 4 * bar_width, latency, bar_width, label='Mean Latency (ms)', color='#FF6666')

# Labels and title
plt.xlabel('Factors')
plt.ylabel('Values')
plt.title('Performance Comparison by Factors with All Metrics')
plt.xticks(index + 2 * bar_width, factors)
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()
